# %%
import numpy as np
import one_matrix_model as om
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt
import observables as ob
import create_distribution as cr
import importlib
importlib.reload(cr)
import Ansatz as an

# %%
results_d_1_N_2 = evolution = np.load("/Users/salsa/MatrixModels/matrixmodels/remote/new_results/run_N=2_D=1_a=1_g_max_1.dipf_evolution.npy", allow_pickle=True)

# %%
times = results_d_1_N_2[0].times
h_exp_val = np.array([ele[0][0] for ele in results_d_1_N_2[0].observables])
plt.plot(times, h_exp_val, label = "varqite")

# %%
states_d_1_N_2 = []
for result in results_d_1_N_2:
    state= Statevector(result.evolved_state)
    states_d_1_N_2.append(state)

# %%
values =[]
for state in states_d_1_N_2:
    expectation = state.expectation_value(om.vandermonde_2(1,2).power(2), list(range(0,4)))
    values.append(expectation)

# %%
g_min = 0.5
g_max  = 1
g_values = np.arange(g_min,g_max, 0.05)
plt.plot(g_values, values)
plt.xlabel('Interaction Strength')
plt.ylabel('interaction_constant')
plt.title('Normalised Z for N = 2, 4 Discretisation Points ')
plt.grid(True)
plt.show()
# Out:
# /Users/salsa/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1340: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
values
# Out:
# [(1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j),
#  (1.0752797426462488+0j)]

# %% [markdown]
# ## N=4, D=1 (2^4 disc points, 2*2 matrix)

# %% [markdown]
# failed

# %%
states = ob.raw_data_to_state("/Users/salsa/MatrixModels/matrixmodels/remote/new_results/run_N=4_D=1_a=1_g_max_1.dipf_evolution.npy")

# %%
partition = ob.calculate_z(states, 4,1)

# %%
g_min = 0.5
g_max  = 1
g_values = np.arange(g_min,g_max, 0.05)
plt.plot(g_values, partition)
plt.xlabel('Interaction Strength')
plt.ylabel('Z value')
plt.title('Normalised Z for N = 2^4, D=1, 16 Discretisation Points, 2*2 Matrix ')
plt.grid(True)
plt.show()
# Out:
# /Users/salsa/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1340: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
times = results[0].times
h_exp_val = np.array([ele[0][0] for ele in results[0].observables])
plt.plot(times, h_exp_val, label = "varqite")

# %%
results = np.load("/Users/salsa/MatrixModels/matrixmodels/remote/new_results/run_N=4_D=1_a=1_g_max_1.dipf_evolution.npy", allow_pickle=True)

# %% [markdown]
# d=0

# %%
results = np.load("/Users/salsa/MatrixModels/matrixmodels/remote/new_results/crankupN8D0g0.01_evolution.npy",allow_pickle=True)

# %%
varqite_result = results[0:7]
scipy_result = results[7:]

# %%
results[6]

# %%
counter = 0
for i in np.arange(7):
    cr.compare_results(varqite_result[i], scipy_result[i], i+2, 1)

# %% [markdown]
# # Ansatz tryouts

# %%
thetas = varqite_result[4].parameter_values
print(thetas[-1])
# Out:
# [ 1.57079648e+00 -4.77395392e+00  1.57079603e+00  1.58006056e+00
#   4.67733593e+00  3.17893039e+00 -2.95951063e-01 -1.53944141e-01
#  -1.12384536e-01 -7.69151419e-05 -1.00172021e-04 -5.43962938e-04
#   1.57079626e+00  8.42288082e+00  1.67851942e+00  1.30046687e+00
#  -1.64186289e-01 -3.08845685e+00 -5.99530595e-01  3.14976105e-01
#   1.12384339e-01  7.69194218e-05  1.00173356e-04 -5.44348726e-04
#  -6.21346343e-01 -1.07731443e-01 -4.45254307e-01 -2.13474158e+00
#   3.75532421e+00  1.08598817e+00  3.44930035e-01  1.13558394e-01
#  -2.36894848e-04  3.18686188e-04 -5.44155832e-04  7.93012101e-06
#   6.27371690e+00  6.22414989e+00 -7.89026693e+00 -4.42360925e-01
#   3.74473548e+00  6.01472825e-02 -1.42537026e-04  2.72481151e-04
#  -1.96558105e-04 -5.55506616e+00 -5.72123019e+00 -1.62272868e-01
#  -5.94759002e-01  3.14957233e-01  1.12383078e-01  7.94339113e-05
#   8.90321095e-05 -5.44298662e-04  2.52189018e-01  4.29320520e-01
# ...

# %%
an.ansatz_review_exact_full_cry(4,1).bind_parameters(thetas[-1]).draw("mpl")
# Out:
# 2

# %%
an.ansatz_review_exact_full_cry(6,1).bind_parameters(thetas[-1]).draw("mpl")
# Out:
# 9

# %%
an.ansatz_review_exact_full_cry(8,1).bind_parameters(thetas[-1]).draw("mpl")
# Out:
# 20

# %%
an.ansatz_review_exact_full_cry(10,1).bind_parameters(thetas[-1]).draw("mpl")
# Out:
# 35

# %%
an.ansatz_review_exact_full_cry(12,1).bind_parameters(thetas[-1]).draw("mpl")
# Out:
# 54
