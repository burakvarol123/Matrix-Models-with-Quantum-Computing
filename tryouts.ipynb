# %%
import create_distribution as cr
import Hamilton as hm
import numpy as np
from create_distribution import *
import importlib
importlib.reload(cr)
from utility import generate_combinations
import hamiltonian_2 as hm2
importlib.reload(hm2)
import one_matrix_model as onem

# %%
D = 1
N =3
a =1
power =2
depth =1
beta =1
qubits = (d+1)*N

lambdas = []
for i in range(D+1):
    lambdas.append(onem.create_lambda_2(i, D, N))
hamiltonian = 0
for i in range(D+1):
    hamiltonian += (a ** 2) * lambdas[i].power(power)

# %%
ansatz =  an.ansatz_review_exact(qubits*2, depth)

# %%
scipy =  create_distribution_scipy(qubits, 2, hamiltonian, beta)

# %%
varqite = np.load("/Users/salsa/MatrixModels/matrixmodels/remote/results/run03_pauli.dipf_evolution.npy",allow_pickle=True)

# %%
varqite.evolved_state
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 varqite.evolved_state
#
# AttributeError: 'numpy.ndarray' object has no attribute 'evolved_state'

# %%
thetas=[ 5.65746527e-02,  5.86764492e-01,  1.57079633e+00,  5.65746527e-02,
  5.86764492e-01,  1.57079633e+00,  4.83424037e-17,  4.28806011e-17,
  9.88365444e-17,  4.30644541e-17, -9.68690602e-18, -2.41426163e-17,
 -1.60089112e-17,  1.60941997e-17,  5.32208604e-17,  4.55865382e-17,
  1.94810289e-17, -2.60859043e-18, -1.16681838e-17, -5.06972936e-18,
 -1.31394461e-17, -1.18356930e-17,  1.92554306e-18, -1.98105421e-17]

binded = an.ansatz_review_exact(12, 1).bind_parameters(thetas)
state = Statevector(binded)

# %%
evolution_result = varqite[3]
sol= scipy[1]
h_exp_val = varqite[2]
exact_h_exp_val = scipy[0]
qubits = 2
beta = 1
compare_results(evolution_result, sol, h_exp_val, exact_h_exp_val, qubits, beta)

# %%
generate_combinations(1)
# Out:
# ['11', '10', '00', '01']

# %%
print(np.arange(2))
# Out:
# [0 1]

# %%
hamilton = hm2.hamiltonian(1,1,2)
create_distribution_2_varqite(1,1,hamilton,0.25)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 hamilton = hm2.hamiltonian(1,1,2)
#       2 create_distribution_2_varqite(1,1,hamilton,0.25)
#
# File ~/MatrixModels/matrixmodels/remote/hamiltonian_2.py:61, in hamiltonian(number_of_qubits, lattice_spacing, pow)
#      56 def hamiltonian(
#      57         number_of_qubits,
#      58         lattice_spacing,
#      59         pow
#      60         ):
# ---> 61     x = position_x(number_of_qubits)
#      62     mat = lattice_spacing ** 2 * x.power(pow)
#      63     return mat
#
# File ~/MatrixModels/matrixmodels/remote/hamiltonian_2.py:53, in position_x(number_of_qubits)
#      49 def position_x(
#      50         number_of_qubits
#      51         ):
#      52     id = SparsePauliOp(["Z"], ["1"] ) ^ insert_i(number_of_qubits- 1)
# ---> 53     id_2 = SparsePauliOp(["Z"], ["1"] ) ^ k_total(number_of_qubits - 1)
#      54     return 0.5 * id +id_2
#
# File ~/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/qiskit/quantum_info/operators/mixins/group.py:62, in GroupMixin.__xor__(self, other)
#      61 def __xor__(self, other) -> Self:
# ---> 62     return self.tensor(other)
#
# File ~/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/qiskit/quantum_info/operators/symplectic/sparse_pauli_op.py:358, in SparsePauliOp.tensor(self, other)
#     356 def tensor(self, other: SparsePauliOp) -> SparsePauliOp:
#     357     if not isinstance(other, SparsePauliOp):
# --> 358         other = SparsePauliOp(other)
#     359     return self._tensor(self, other)
#
# File ~/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/qiskit/quantum_info/operators/symplectic/sparse_pauli_op.py:127, in SparsePauliOp.__init__(self, data, coeffs, ignore_pauli_phase, copy)
#     123     # `SparsePauliOp._pauli_list` is already compatible with the internal ZX-phase
#     124     # convention.  See `BasePauli._from_array` for the internal ZX-phase convention.
#     125     ignore_pauli_phase = True
# --> 127 pauli_list = PauliList(data.copy() if copy and hasattr(data, "copy") else data)
#     129 if isinstance(coeffs, np.ndarray) and coeffs.dtype == object:
#     130     dtype = object
#
# File ~/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/qiskit/quantum_info/operators/symplectic/pauli_list.py:145, in PauliList.__init__(self, data)
#     142     base_z, base_x, base_phase = self._from_array(data.Z, data.X)
#     143 else:
#     144     # Conversion as iterable of Paulis
# --> 145     base_z, base_x, base_phase = self._from_paulis(data)
#     147 # Initialize BasePauli
#     148 super().__init__(base_z, base_x, base_phase)
#
# File ~/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/qiskit/quantum_info/operators/symplectic/pauli_list.py:190, in PauliList._from_paulis(data)
#     188 for i in data:
#     189     if not isinstance(i, Pauli):
# --> 190         paulis.append(Pauli(i))
#     191     else:
#     192         paulis.append(i)
#
# File ~/anaconda3/envs/MatrixModels/lib/python3.11/site-packages/qiskit/quantum_info/operators/symplectic/pauli.py:217, in Pauli.__init__(self, data, x, z, label)
#     215     base_z, base_x, base_phase = self._from_label(label)
#     216 else:
# --> 217     raise QiskitError("Invalid input data for Pauli.")
#     219 # Initialize BasePauli
#     220 if base_z.shape[0] != 1:
#
# QiskitError: 'Invalid input data for Pauli.'

# %%
vander = onem.vandermonde_2(1,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 binded = an.ansatz_review_exact(12, 1).bind_parameters(thetas)
#       3 state = Statevector(binded)
#       4 vander = onem.vandermonde_2(1,3)
#
# NameError: name 'an' is not defined

# %%
result = state.expectation_value(vander.power(6),[0,1,2,3,4,5])

# %%
result
# Out:
# (9.111277220622208+0j)

# %%
import numpy as np

# %%
file = np.load("/Users/salsa/MatrixModels/matrixmodels/remote/results/scipyresult.npy",allow_pickle = True)

# %%
file
# Out:
# array([array([2.5       , 2.46000533, 2.42004264, 2.38014379, 2.34034046,
#               2.30066401, 2.2611454 , 2.2218151 , 2.18270299, 2.14383826,
#               2.10524936, 2.06696388, 2.0290085 , 1.99140893, 1.95418984,
#               1.91737478, 1.88098616, 1.84504521, 1.80957193, 1.77458506,
#               1.74010208, 1.70613914, 1.67271112, 1.63983158, 1.60751278,
#               1.57576569, 1.54459998, 1.51402407, 1.48404513, 1.45466914,
#               1.42590087, 1.39774394, 1.37020089, 1.34327317, 1.31696121,
#               1.29126445])                                               ,
#        <qiskit.algorithms.time_evolvers.time_evolution_result.TimeEvolutionResult object at 0x10e307d50>],
#       dtype=object)
